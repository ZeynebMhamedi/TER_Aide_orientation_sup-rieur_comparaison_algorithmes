# %% [markdown]
# # TER: Aide à l’orientation dans le supérieur : ANN (2 classes)

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/My Drive/Colab Notebooks/TER/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import seaborn as sns

# %% [markdown]
# ### Selection du nouveau train set et test set précédemment générés

# %%
# données de train
df1_train = pd.read_csv(path+'generated_data_class2/train1.csv')
df2_train = pd.read_csv(path+'generated_data_class2/train2.csv')
df3_train = pd.read_csv(path+'generated_data_class2/train3.csv')
df4_train = pd.read_csv(path+'generated_data_class2/train4.csv')
df5_train = pd.read_csv(path+'generated_data_class2/train5.csv')
df6_train = pd.read_csv(path+'generated_data_class2/train6.csv')
df7_train = pd.read_csv(path+'generated_data_class2/train7.csv')
df8_train = pd.read_csv(path+'generated_data_class2/train8.csv')
df9_train = pd.read_csv(path+'generated_data_class2/train9.csv')
df10_train = pd.read_csv(path+'generated_data_class2/train10.csv')
df11_train = pd.read_csv(path+'generated_data_class2/train11.csv')
df12_train = pd.read_csv(path+'generated_data_class2/train12.csv')
df13_train = pd.read_csv(path+'generated_data_class2/train13.csv')
df14_train = pd.read_csv(path+'generated_data_class2/train14.csv')
df15_train = pd.read_csv(path+'generated_data_class2/train15.csv')

#données de test
df1_test = pd.read_csv(path+'generated_data_class2/test1.csv')
df2_test = pd.read_csv(path+'generated_data_class2/test2.csv')
df3_test = pd.read_csv(path+'generated_data_class2/test3.csv')
df4_test = pd.read_csv(path+'generated_data_class2/test4.csv')
df5_test = pd.read_csv(path+'generated_data_class2/test5.csv')
df6_test = pd.read_csv(path+'generated_data_class2/test6.csv')
df7_test = pd.read_csv(path+'generated_data_class2/test7.csv')
df8_test = pd.read_csv(path+'generated_data_class2/test8.csv')
df9_test = pd.read_csv(path+'generated_data_class2/test9.csv')
df10_test = pd.read_csv(path+'generated_data_class2/test10.csv')
df11_test = pd.read_csv(path+'generated_data_class2/test11.csv')
df12_test = pd.read_csv(path+'generated_data_class2/test12.csv')
df13_test = pd.read_csv(path+'generated_data_class2/test13.csv')
df14_test = pd.read_csv(path+'generated_data_class2/test14.csv')
df15_test = pd.read_csv(path+'generated_data_class2/test15.csv')

df_train = [df1_train,df2_train,df3_train,df4_train,df5_train,df6_train,df7_train,df8_train,df9_train,df10_train,df11_train,df12_train,df13_train,df14_train,df15_train]
df_test = [df1_test,df2_test,df3_test,df4_test,df5_test,df6_test,df7_test,df8_test,df9_test,df10_test,df11_test,df12_test,df13_test,df14_test,df15_test]

# %%
#résultats des élèves classe 0(echecs) ou 1(reussites)
y_col = 'resultats_iut_tdats1'

# %% [markdown]
# ### Prepare data

# %%
X_train,y_train,X_test,y_test = [],[],[],[]

for i in range(15):
    dfi_train = df_train[i]
    dfi_test = df_test[i]
    y_train.append(dfi_train[y_col])
    X_train.append(dfi_train[dfi_train.columns.drop(y_col)])
    y_test.append(dfi_test[y_col])
    X_test.append(dfi_test[dfi_test.columns.drop(y_col)])
    sc = StandardScaler()
    X_train[i] = sc.fit_transform(X_train[i])
    X_test[i] = sc.transform(X_test[i])

# %% [markdown]
# ## Metrics

# %%
from keras import backend as K

def recall(y_true, y_pred):
    y_true = K.ones_like(y_true)
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    all_positives = K.sum(K.round(K.clip(y_true, 0, 1)))

    recall = true_positives / (all_positives + K.epsilon())
    return recall

def precision(y_true, y_pred):
    y_true = K.ones_like(y_true)
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))

    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_score(y_true, y_pred):
    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    return 2*((p*r)/(p+r+K.epsilon()))

# %% [markdown]
# ### Réseau de neurones:

# %%
#Initialising ANN
ann1 = tf.keras.models.Sequential()
ann2 = tf.keras.models.Sequential()
ann3 = tf.keras.models.Sequential()
ann4 = tf.keras.models.Sequential()
ann5 = tf.keras.models.Sequential()
ann6 = tf.keras.models.Sequential()
ann7 = tf.keras.models.Sequential()
ann8 = tf.keras.models.Sequential()
ann9 = tf.keras.models.Sequential()
ann10 = tf.keras.models.Sequential()
ann11 = tf.keras.models.Sequential()
ann12 = tf.keras.models.Sequential()
ann13 = tf.keras.models.Sequential()
ann14 = tf.keras.models.Sequential()
ann15 = tf.keras.models.Sequential()

ANN = [ann1,ann2,ann3,ann4,ann5,ann6,ann7,ann8,ann9,ann10,ann11,ann12,ann13,ann14,ann15]

for i in range(len(ANN)):
    #Adding First Hidden Layer
    ANN[i].add(tf.keras.layers.Dense(units=100,activation="relu"))
    #Dropout to avoid over-fitting
    ANN[i].add(tf.keras.layers.Dropout(rate = 0.1)) 
    #Adding Second Hidden Layer
    ANN[i].add(tf.keras.layers.Dense(units=10,activation="relu"))
    #Dropout to avoid over-fitting
    ANN[i].add(tf.keras.layers.Dropout(rate = 0.1))
    #Adding Output Layer
    ANN[i].add(tf.keras.layers.Dense(units=1,activation="sigmoid"))
    #Compiling ANN
    ANN[i].compile(optimizer="adam",loss="mse",metrics=['accuracy', f1_score, precision, recall])

# %% [markdown]
# ### Entrainement avec les 15 datasets

# %%
#Fitting ANN
epoch = 10
history = []

for i in range(15):
    history.append(ANN[i].fit(X_train[i], y_train[i], validation_data=[X_test[i],y_test[i]], batch_size=32, epochs=epoch))
# Out:
# Epoch 1/10
# 3/3 [==============================] - 3s 427ms/step - loss: 0.2992 - accuracy: 0.6064 - f1_score: 0.9894 - precision: 1.0000 - recall: 0.9792 - val_loss: 0.1718 - val_accuracy: 0.8049 - val_f1_score: 0.9706 - val_precision: 1.0000 - val_recall: 0.9444
# Epoch 2/10
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1558 - accuracy: 0.7553 - f1_score: 0.9184 - precision: 1.0000 - recall: 0.8521 - val_loss: 0.1974 - val_accuracy: 0.7805 - val_f1_score: 0.9627 - val_precision: 1.0000 - val_recall: 0.9288
# Epoch 3/10
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0938 - accuracy: 0.8723 - f1_score: 0.8319 - precision: 1.0000 - recall: 0.7132 - val_loss: 0.2161 - val_accuracy: 0.7317 - val_f1_score: 0.9214 - val_precision: 1.0000 - val_recall: 0.8576
# Epoch 4/10
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0603 - accuracy: 0.9362 - f1_score: 0.8166 - precision: 1.0000 - recall: 0.6917 - val_loss: 0.2251 - val_accuracy: 0.7317 - val_f1_score: 0.9214 - val_precision: 1.0000 - val_recall: 0.8576
# Epoch 5/10
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0530 - accuracy: 0.9468 - f1_score: 0.8103 - precision: 1.0000 - recall: 0.6813 - val_loss: 0.2292 - val_accuracy: 0.7073 - val_f1_score: 0.9129 - val_precision: 1.0000 - val_recall: 0.8420
# Epoch 6/10
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0401 - accuracy: 0.9574 - f1_score: 0.8025 - precision: 1.0000 - recall: 0.6708 - val_loss: 0.2298 - val_accuracy: 0.7073 - val_f1_score: 0.9129 - val_precision: 1.0000 - val_recall: 0.8420
# Epoch 7/10
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0312 - accuracy: 0.9787 - f1_score: 0.7817 - precision: 1.0000 - recall: 0.6465 - val_loss: 0.2357 - val_accuracy: 0.6098 - val_f1_score: 0.8483 - val_precision: 1.0000 - val_recall: 0.7396
# Epoch 8/10
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0218 - accuracy: 0.9894 - f1_score: 0.7616 - precision: 1.0000 - recall: 0.6167 - val_loss: 0.2409 - val_accuracy: 0.6341 - val_f1_score: 0.8576 - val_precision: 1.0000 - val_recall: 0.7552
# Epoch 9/10
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0230 - accuracy: 0.9787 - f1_score: 0.7857 - precision: 1.0000 - recall: 0.6486 - val_loss: 0.2457 - val_accuracy: 0.6341 - val_f1_score: 0.8576 - val_precision: 1.0000 - val_recall: 0.7552
# Epoch 10/10
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0166 - accuracy: 0.9894 - f1_score: 0.7791 - precision: 1.0000 - recall: 0.6382 - val_loss: 0.2483 - val_accuracy: 0.6585 - val_f1_score: 0.8667 - val_precision: 1.0000 - val_recall: 0.7708
# Epoch 1/10
# 3/3 [==============================] - 3s 262ms/step - loss: 0.4065 - accuracy: 0.3830 - f1_score: 0.1895 - precision: 1.0000 - recall: 0.1083 - val_loss: 0.3366 - val_accuracy: 0.4634 - val_f1_score: 0.4013 - val_precision: 1.0000 - val_recall: 0.2517
# Epoch 2/10
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1776 - accuracy: 0.7553 - f1_score: 0.6150 - precision: 1.0000 - recall: 0.4542 - val_loss: 0.2467 - val_accuracy: 0.5854 - val_f1_score: 0.7534 - val_precision: 1.0000 - val_recall: 0.6059
# Epoch 3/10
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0718 - accuracy: 0.9362 - f1_score: 0.7773 - precision: 1.0000 - recall: 0.6382 - val_loss: 0.2132 - val_accuracy: 0.6829 - val_f1_score: 0.8483 - val_precision: 1.0000 - val_recall: 0.7396
# Epoch 4/10
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0567 - accuracy: 0.9362 - f1_score: 0.7787 - precision: 1.0000 - recall: 0.6396 - val_loss: 0.2095 - val_accuracy: 0.7317 - val_f1_score: 0.8483 - val_precision: 1.0000 - val_recall: 0.7396
# Epoch 5/10
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0383 - accuracy: 0.9894 - f1_score: 0.7964 - precision: 1.0000 - recall: 0.6674 - val_loss: 0.2128 - val_accuracy: 0.7317 - val_f1_score: 0.8483 - val_precision: 1.0000 - val_recall: 0.7396
# Epoch 6/10
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0228 - accuracy: 0.9787 - f1_score: 0.7937 - precision: 1.0000 - recall: 0.6590 - val_loss: 0.2185 - val_accuracy: 0.7073 - val_f1_score: 0.8858 - val_precision: 1.0000 - val_recall: 0.7951
# Epoch 7/10
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0189 - accuracy: 0.9894 - f1_score: 0.8026 - precision: 1.0000 - recall: 0.6715 - val_loss: 0.2243 - val_accuracy: 0.6829 - val_f1_score: 0.8951 - val_precision: 1.0000 - val_recall: 0.8108
# Epoch 8/10
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0163 - accuracy: 0.9894 - f1_score: 0.8163 - precision: 1.0000 - recall: 0.6937 - val_loss: 0.2307 - val_accuracy: 0.6829 - val_f1_score: 0.8951 - val_precision: 1.0000 - val_recall: 0.8108
# Epoch 9/10
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0153 - accuracy: 0.9894 - f1_score: 0.8158 - precision: 1.0000 - recall: 0.6903 - val_loss: 0.2366 - val_accuracy: 0.6829 - val_f1_score: 0.8951 - val_precision: 1.0000 - val_recall: 0.8108
# Epoch 10/10
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0134 - accuracy: 0.9787 - f1_score: 0.8158 - precision: 1.0000 - recall: 0.6986 - val_loss: 0.2375 - val_accuracy: 0.6829 - val_f1_score: 0.8951 - val_precision: 1.0000 - val_recall: 0.8108
# Epoch 1/10
# 3/3 [==============================] - 2s 165ms/step - loss: 0.3020 - accuracy: 0.4043 - f1_score: 0.3773 - precision: 1.0000 - recall: 0.2354 - val_loss: 0.2880 - val_accuracy: 0.4634 - val_f1_score: 0.5227 - val_precision: 1.0000 - val_recall: 0.3542
# Epoch 2/10
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1539 - accuracy: 0.7447 - f1_score: 0.6171 - precision: 1.0000 - recall: 0.4486 - val_loss: 0.2485 - val_accuracy: 0.6098 - val_f1_score: 0.6100 - val_precision: 1.0000 - val_recall: 0.4479
# Epoch 3/10
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1055 - accuracy: 0.8617 - f1_score: 0.7202 - precision: 1.0000 - recall: 0.5660 - val_loss: 0.2344 - val_accuracy: 0.6341 - val_f1_score: 0.7363 - val_precision: 1.0000 - val_recall: 0.5972
# Epoch 4/10
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0821 - accuracy: 0.9574 - f1_score: 0.7780 - precision: 1.0000 - recall: 0.6375 - val_loss: 0.2332 - val_accuracy: 0.6341 - val_f1_score: 0.7957 - val_precision: 1.0000 - val_recall: 0.6684
# Epoch 5/10
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0564 - accuracy: 0.9468 - f1_score: 0.7860 - precision: 1.0000 - recall: 0.6514 - val_loss: 0.2326 - val_accuracy: 0.6341 - val_f1_score: 0.7957 - val_precision: 1.0000 - val_recall: 0.6684
# Epoch 6/10
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0525 - accuracy: 0.9574 - f1_score: 0.7773 - precision: 1.0000 - recall: 0.6382 - val_loss: 0.2259 - val_accuracy: 0.6585 - val_f1_score: 0.7857 - val_precision: 1.0000 - val_recall: 0.6528
# Epoch 7/10
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0490 - accuracy: 0.9681 - f1_score: 0.7985 - precision: 1.0000 - recall: 0.6681 - val_loss: 0.2238 - val_accuracy: 0.6585 - val_f1_score: 0.7857 - val_precision: 1.0000 - val_recall: 0.6528
# Epoch 8/10
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0332 - accuracy: 0.9787 - f1_score: 0.7945 - precision: 1.0000 - recall: 0.6604 - val_loss: 0.2240 - val_accuracy: 0.6585 - val_f1_score: 0.8386 - val_precision: 1.0000 - val_recall: 0.7240
# Epoch 9/10
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0248 - accuracy: 0.9787 - f1_score: 0.7933 - precision: 1.0000 - recall: 0.6604 - val_loss: 0.2302 - val_accuracy: 0.6585 - val_f1_score: 0.8576 - val_precision: 1.0000 - val_recall: 0.7552
# Epoch 10/10
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0223 - accuracy: 0.9787 - f1_score: 0.7943 - precision: 1.0000 - recall: 0.6590 - val_loss: 0.2380 - val_accuracy: 0.6585 - val_f1_score: 0.9042 - val_precision: 1.0000 - val_recall: 0.8264
# Epoch 1/10
# 3/3 [==============================] - 2s 173ms/step - loss: 0.2465 - accuracy: 0.7128 - f1_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3037 - val_accuracy: 0.6341 - val_f1_score: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 2/10
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1607 - accuracy: 0.7340 - f1_score: 0.9885 - precision: 1.0000 - recall: 0.9778 - val_loss: 0.2734 - val_accuracy: 0.6341 - val_f1_score: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 3/10
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0886 - accuracy: 0.8191 - f1_score: 0.9413 - precision: 1.0000 - recall: 0.8917 - val_loss: 0.2516 - val_accuracy: 0.6585 - val_f1_score: 0.9129 - val_precision: 1.0000 - val_recall: 0.8420
# Epoch 4/10
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0535 - accuracy: 0.9574 - f1_score: 0.8593 - precision: 1.0000 - recall: 0.7542 - val_loss: 0.2495 - val_accuracy: 0.6829 - val_f1_score: 0.9042 - val_precision: 1.0000 - val_recall: 0.8264
# Epoch 5/10
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0452 - accuracy: 0.9574 - f1_score: 0.8428 - precision: 1.0000 - recall: 0.7347 - val_loss: 0.2491 - val_accuracy: 0.6585 - val_f1_score: 0.8951 - val_precision: 1.0000 - val_recall: 0.8108
# Epoch 6/10
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0333 - accuracy: 0.9894 - f1_score: 0.8379 - precision: 1.0000 - recall: 0.7222 - val_loss: 0.2503 - val_accuracy: 0.7073 - val_f1_score: 0.8483 - val_precision: 1.0000 - val_recall: 0.7396
# Epoch 7/10
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0288 - accuracy: 0.9894 - f1_score: 0.8385 - precision: 1.0000 - recall: 0.7229 - val_loss: 0.2528 - val_accuracy: 0.7073 - val_f1_score: 0.8483 - val_precision: 1.0000 - val_recall: 0.7396
# Epoch 8/10
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0240 - accuracy: 0.9894 - f1_score: 0.8390 - precision: 1.0000 - recall: 0.7229 - val_loss: 0.2566 - val_accuracy: 0.7073 - val_f1_score: 0.8483 - val_precision: 1.0000 - val_recall: 0.7396
# Epoch 9/10
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0205 - accuracy: 0.9894 - f1_score: 0.8397 - precision: 1.0000 - recall: 0.7243 - val_loss: 0.2608 - val_accuracy: 0.7073 - val_f1_score: 0.8483 - val_precision: 1.0000 - val_recall: 0.7396
# Epoch 10/10
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0260 - accuracy: 0.9787 - f1_score: 0.8312 - precision: 1.0000 - recall: 0.7118 - val_loss: 0.2640 - val_accuracy: 0.6585 - val_f1_score: 0.7957 - val_precision: 1.0000 - val_recall: 0.6684
# Epoch 1/10
# 3/3 [==============================] - 2s 167ms/step - loss: 0.3412 - accuracy: 0.4468 - f1_score: 0.4944 - precision: 1.0000 - recall: 0.3292 - val_loss: 0.2963 - val_accuracy: 0.5122 - val_f1_score: 0.5767 - val_precision: 1.0000 - val_recall: 0.4184
# Epoch 2/10
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1175 - accuracy: 0.8404 - f1_score: 0.6872 - precision: 1.0000 - recall: 0.5292 - val_loss: 0.2627 - val_accuracy: 0.5610 - val_f1_score: 0.6763 - val_precision: 1.0000 - val_recall: 0.5122
# Epoch 3/10
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0375 - accuracy: 0.9787 - f1_score: 0.7847 - precision: 1.0000 - recall: 0.6521 - val_loss: 0.2466 - val_accuracy: 0.6341 - val_f1_score: 0.7418 - val_precision: 1.0000 - val_recall: 0.5903
# Epoch 4/10
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0375 - accuracy: 0.9468 - f1_score: 0.7773 - precision: 1.0000 - recall: 0.6382 - val_loss: 0.2328 - val_accuracy: 0.6341 - val_f1_score: 0.7962 - val_precision: 1.0000 - val_recall: 0.6615
# Epoch 5/10
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0128 - accuracy: 1.0000 - f1_score: 0.7991 - precision: 1.0000 - recall: 0.6701 - val_loss: 0.2244 - val_accuracy: 0.6829 - val_f1_score: 0.8221 - val_precision: 1.0000 - val_recall: 0.7014
# Epoch 6/10
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0124 - accuracy: 0.9894 - f1_score: 0.7941 - precision: 1.0000 - recall: 0.6618 - val_loss: 0.2196 - val_accuracy: 0.6829 - val_f1_score: 0.8449 - val_precision: 1.0000 - val_recall: 0.7326
# Epoch 7/10
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0046 - accuracy: 1.0000 - f1_score: 0.8008 - precision: 1.0000 - recall: 0.6715 - val_loss: 0.2162 - val_accuracy: 0.6585 - val_f1_score: 0.8337 - val_precision: 1.0000 - val_recall: 0.7170
# Epoch 8/10
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0148 - accuracy: 0.9894 - f1_score: 0.7951 - precision: 1.0000 - recall: 0.6604 - val_loss: 0.2183 - val_accuracy: 0.6585 - val_f1_score: 0.8337 - val_precision: 1.0000 - val_recall: 0.7170
# Epoch 9/10
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0106 - accuracy: 0.9787 - f1_score: 0.7868 - precision: 1.0000 - recall: 0.6486 - val_loss: 0.2255 - val_accuracy: 0.6341 - val_f1_score: 0.8449 - val_precision: 1.0000 - val_recall: 0.7326
# Epoch 10/10
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0072 - accuracy: 1.0000 - f1_score: 0.7939 - precision: 1.0000 - recall: 0.6743 - val_loss: 0.2292 - val_accuracy: 0.6829 - val_f1_score: 0.8182 - val_precision: 1.0000 - val_recall: 0.6927
# Epoch 1/10
# 3/3 [==============================] - 2s 182ms/step - loss: 0.3229 - accuracy: 0.4468 - f1_score: 0.6876 - precision: 1.0000 - recall: 0.5354 - val_loss: 0.2039 - val_accuracy: 0.7317 - val_f1_score: 0.7534 - val_precision: 1.0000 - val_recall: 0.6059
# Epoch 2/10
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1178 - accuracy: 0.8511 - f1_score: 0.8101 - precision: 1.0000 - recall: 0.6819 - val_loss: 0.1863 - val_accuracy: 0.8049 - val_f1_score: 0.7857 - val_precision: 1.0000 - val_recall: 0.6528
# Epoch 3/10
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0525 - accuracy: 0.9468 - f1_score: 0.8297 - precision: 1.0000 - recall: 0.7111 - val_loss: 0.1944 - val_accuracy: 0.7561 - val_f1_score: 0.7857 - val_precision: 1.0000 - val_recall: 0.6528
# Epoch 4/10
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0469 - accuracy: 0.9574 - f1_score: 0.7929 - precision: 1.0000 - recall: 0.6583 - val_loss: 0.2067 - val_accuracy: 0.7317 - val_f1_score: 0.8483 - val_precision: 1.0000 - val_recall: 0.7396
# Epoch 5/10
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0305 - accuracy: 0.9681 - f1_score: 0.8025 - precision: 1.0000 - recall: 0.6708 - val_loss: 0.2188 - val_accuracy: 0.6585 - val_f1_score: 0.8182 - val_precision: 1.0000 - val_recall: 0.6927
# Epoch 6/10
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0235 - accuracy: 0.9787 - f1_score: 0.7947 - precision: 1.0000 - recall: 0.6597 - val_loss: 0.2289 - val_accuracy: 0.6829 - val_f1_score: 0.8286 - val_precision: 1.0000 - val_recall: 0.7083
# Epoch 7/10
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0150 - accuracy: 0.9894 - f1_score: 0.7861 - precision: 1.0000 - recall: 0.6500 - val_loss: 0.2359 - val_accuracy: 0.6829 - val_f1_score: 0.8286 - val_precision: 1.0000 - val_recall: 0.7083
# Epoch 8/10
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0221 - accuracy: 0.9787 - f1_score: 0.7793 - precision: 1.0000 - recall: 0.6396 - val_loss: 0.2396 - val_accuracy: 0.6829 - val_f1_score: 0.8286 - val_precision: 1.0000 - val_recall: 0.7083
# Epoch 9/10
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0134 - accuracy: 0.9894 - f1_score: 0.7855 - precision: 1.0000 - recall: 0.6493 - val_loss: 0.2414 - val_accuracy: 0.6829 - val_f1_score: 0.8286 - val_precision: 1.0000 - val_recall: 0.7083
# Epoch 10/10
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0182 - accuracy: 0.9787 - f1_score: 0.7895 - precision: 1.0000 - recall: 0.6569 - val_loss: 0.2416 - val_accuracy: 0.7073 - val_f1_score: 0.7857 - val_precision: 1.0000 - val_recall: 0.6528
# Epoch 1/10
# 3/3 [==============================] - 2s 175ms/step - loss: 0.2368 - accuracy: 0.6064 - f1_score: 0.8744 - precision: 1.0000 - recall: 0.7771 - val_loss: 0.2510 - val_accuracy: 0.6341 - val_f1_score: 0.9576 - val_precision: 1.0000 - val_recall: 0.9219
# Epoch 2/10
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1102 - accuracy: 0.8404 - f1_score: 0.8870 - precision: 1.0000 - recall: 0.7972 - val_loss: 0.2449 - val_accuracy: 0.6585 - val_f1_score: 0.9667 - val_precision: 1.0000 - val_recall: 0.9375
# Epoch 3/10
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0621 - accuracy: 0.9255 - f1_score: 0.8443 - precision: 1.0000 - recall: 0.7326 - val_loss: 0.2450 - val_accuracy: 0.6829 - val_f1_score: 0.8951 - val_precision: 1.0000 - val_recall: 0.8108
# Epoch 4/10
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0406 - accuracy: 0.9787 - f1_score: 0.8214 - precision: 1.0000 - recall: 0.7000 - val_loss: 0.2438 - val_accuracy: 0.6829 - val_f1_score: 0.8483 - val_precision: 1.0000 - val_recall: 0.7396
# Epoch 5/10
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0307 - accuracy: 0.9681 - f1_score: 0.8190 - precision: 1.0000 - recall: 0.7083 - val_loss: 0.2396 - val_accuracy: 0.6585 - val_f1_score: 0.7857 - val_precision: 1.0000 - val_recall: 0.6528
# Epoch 6/10
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0181 - accuracy: 0.9894 - f1_score: 0.8155 - precision: 1.0000 - recall: 0.6910 - val_loss: 0.2392 - val_accuracy: 0.6585 - val_f1_score: 0.7857 - val_precision: 1.0000 - val_recall: 0.6528
# Epoch 7/10
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0225 - accuracy: 0.9787 - f1_score: 0.8103 - precision: 1.0000 - recall: 0.6813 - val_loss: 0.2443 - val_accuracy: 0.6098 - val_f1_score: 0.7646 - val_precision: 1.0000 - val_recall: 0.6215
# Epoch 8/10
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0220 - accuracy: 0.9787 - f1_score: 0.8246 - precision: 1.0000 - recall: 0.7042 - val_loss: 0.2502 - val_accuracy: 0.6098 - val_f1_score: 0.7646 - val_precision: 1.0000 - val_recall: 0.6215
# Epoch 9/10
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0159 - accuracy: 1.0000 - f1_score: 0.8088 - precision: 1.0000 - recall: 0.6806 - val_loss: 0.2556 - val_accuracy: 0.6098 - val_f1_score: 0.7646 - val_precision: 1.0000 - val_recall: 0.6215
# Epoch 10/10
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0099 - accuracy: 1.0000 - f1_score: 0.8073 - precision: 1.0000 - recall: 0.6792 - val_loss: 0.2617 - val_accuracy: 0.5854 - val_f1_score: 0.7534 - val_precision: 1.0000 - val_recall: 0.6059
# Epoch 1/10
# 3/3 [==============================] - 2s 183ms/step - loss: 0.2672 - accuracy: 0.5532 - f1_score: 0.8097 - precision: 1.0000 - recall: 0.6813 - val_loss: 0.2149 - val_accuracy: 0.7073 - val_f1_score: 0.9074 - val_precision: 1.0000 - val_recall: 0.8438
# Epoch 2/10
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0834 - accuracy: 0.9043 - f1_score: 0.8298 - precision: 1.0000 - recall: 0.7125 - val_loss: 0.2054 - val_accuracy: 0.7317 - val_f1_score: 0.9189 - val_precision: 1.0000 - val_recall: 0.8507
# Epoch 3/10
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0274 - accuracy: 0.9681 - f1_score: 0.8178 - precision: 1.0000 - recall: 0.6924 - val_loss: 0.2153 - val_accuracy: 0.7317 - val_f1_score: 0.9189 - val_precision: 1.0000 - val_recall: 0.8507
# Epoch 4/10
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0148 - accuracy: 0.9894 - f1_score: 0.8150 - precision: 1.0000 - recall: 0.6931 - val_loss: 0.2280 - val_accuracy: 0.7561 - val_f1_score: 0.9092 - val_precision: 1.0000 - val_recall: 0.8351
# Epoch 5/10
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0125 - accuracy: 0.9787 - f1_score: 0.8101 - precision: 1.0000 - recall: 0.6819 - val_loss: 0.2326 - val_accuracy: 0.7561 - val_f1_score: 0.9092 - val_precision: 1.0000 - val_recall: 0.8351
# Epoch 6/10
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0203 - accuracy: 0.9787 - f1_score: 0.8097 - precision: 1.0000 - recall: 0.6813 - val_loss: 0.2364 - val_accuracy: 0.7317 - val_f1_score: 0.8992 - val_precision: 1.0000 - val_recall: 0.8194
# Epoch 7/10
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0169 - accuracy: 0.9787 - f1_score: 0.8103 - precision: 1.0000 - recall: 0.6813 - val_loss: 0.2397 - val_accuracy: 0.7317 - val_f1_score: 0.8992 - val_precision: 1.0000 - val_recall: 0.8194
# Epoch 8/10
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0136 - accuracy: 0.9894 - f1_score: 0.8024 - precision: 1.0000 - recall: 0.6701 - val_loss: 0.2425 - val_accuracy: 0.7073 - val_f1_score: 0.8888 - val_precision: 1.0000 - val_recall: 0.8038
# Epoch 9/10
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0221 - accuracy: 0.9681 - f1_score: 0.8017 - precision: 1.0000 - recall: 0.6708 - val_loss: 0.2439 - val_accuracy: 0.7073 - val_f1_score: 0.8888 - val_precision: 1.0000 - val_recall: 0.8038
# Epoch 10/10
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0114 - accuracy: 0.9894 - f1_score: 0.8014 - precision: 1.0000 - recall: 0.6694 - val_loss: 0.2429 - val_accuracy: 0.6829 - val_f1_score: 0.8780 - val_precision: 1.0000 - val_recall: 0.7882
# Epoch 1/10
# 3/3 [==============================] - 1s 166ms/step - loss: 0.2696 - accuracy: 0.4574 - f1_score: 0.7945 - precision: 1.0000 - recall: 0.6722 - val_loss: 0.2829 - val_accuracy: 0.6098 - val_f1_score: 0.8386 - val_precision: 1.0000 - val_recall: 0.7240
# Epoch 2/10
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1462 - accuracy: 0.8298 - f1_score: 0.8529 - precision: 1.0000 - recall: 0.7465 - val_loss: 0.2572 - val_accuracy: 0.6098 - val_f1_score: 0.8576 - val_precision: 1.0000 - val_recall: 0.7552
# Epoch 3/10
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0930 - accuracy: 0.8723 - f1_score: 0.8674 - precision: 1.0000 - recall: 0.7660 - val_loss: 0.2458 - val_accuracy: 0.6341 - val_f1_score: 0.8667 - val_precision: 1.0000 - val_recall: 0.7708
# Epoch 4/10
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0736 - accuracy: 0.9043 - f1_score: 0.8461 - precision: 1.0000 - recall: 0.7340 - val_loss: 0.2355 - val_accuracy: 0.6829 - val_f1_score: 0.9129 - val_precision: 1.0000 - val_recall: 0.8420
# Epoch 5/10
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0566 - accuracy: 0.9043 - f1_score: 0.8178 - precision: 1.0000 - recall: 0.6924 - val_loss: 0.2346 - val_accuracy: 0.6829 - val_f1_score: 0.9129 - val_precision: 1.0000 - val_recall: 0.8420
# Epoch 6/10
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0372 - accuracy: 0.9574 - f1_score: 0.8381 - precision: 1.0000 - recall: 0.7243 - val_loss: 0.2366 - val_accuracy: 0.6829 - val_f1_score: 0.9129 - val_precision: 1.0000 - val_recall: 0.8420
# Epoch 7/10
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0290 - accuracy: 0.9574 - f1_score: 0.8249 - precision: 1.0000 - recall: 0.7021 - val_loss: 0.2418 - val_accuracy: 0.6829 - val_f1_score: 0.9129 - val_precision: 1.0000 - val_recall: 0.8420
# Epoch 8/10
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0290 - accuracy: 0.9468 - f1_score: 0.8431 - precision: 1.0000 - recall: 0.7319 - val_loss: 0.2442 - val_accuracy: 0.6829 - val_f1_score: 0.9129 - val_precision: 1.0000 - val_recall: 0.8420
# Epoch 9/10
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0389 - accuracy: 0.9255 - f1_score: 0.8466 - precision: 1.0000 - recall: 0.7347 - val_loss: 0.2452 - val_accuracy: 0.6829 - val_f1_score: 0.9129 - val_precision: 1.0000 - val_recall: 0.8420
# Epoch 10/10
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0197 - accuracy: 0.9468 - f1_score: 0.8466 - precision: 1.0000 - recall: 0.7347 - val_loss: 0.2480 - val_accuracy: 0.6829 - val_f1_score: 0.9129 - val_precision: 1.0000 - val_recall: 0.8420
# Epoch 1/10
# 3/3 [==============================] - 2s 160ms/step - loss: 0.2439 - accuracy: 0.5957 - f1_score: 0.8002 - precision: 1.0000 - recall: 0.6708 - val_loss: 0.2296 - val_accuracy: 0.5854 - val_f1_score: 0.8221 - val_precision: 1.0000 - val_recall: 0.7014
# Epoch 2/10
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1004 - accuracy: 0.8723 - f1_score: 0.8163 - precision: 1.0000 - recall: 0.6937 - val_loss: 0.2411 - val_accuracy: 0.5854 - val_f1_score: 0.7469 - val_precision: 1.0000 - val_recall: 0.5990
# Epoch 3/10
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0505 - accuracy: 0.9681 - f1_score: 0.7924 - precision: 1.0000 - recall: 0.6597 - val_loss: 0.2493 - val_accuracy: 0.6585 - val_f1_score: 0.7844 - val_precision: 1.0000 - val_recall: 0.6545
# Epoch 4/10
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0332 - accuracy: 0.9681 - f1_score: 0.7878 - precision: 1.0000 - recall: 0.6618 - val_loss: 0.2526 - val_accuracy: 0.6098 - val_f1_score: 0.7566 - val_precision: 1.0000 - val_recall: 0.6233
# Epoch 5/10
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0315 - accuracy: 0.9468 - f1_score: 0.7904 - precision: 1.0000 - recall: 0.6597 - val_loss: 0.2530 - val_accuracy: 0.6098 - val_f1_score: 0.7566 - val_precision: 1.0000 - val_recall: 0.6233
# Epoch 6/10
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0147 - accuracy: 1.0000 - f1_score: 0.7873 - precision: 1.0000 - recall: 0.6500 - val_loss: 0.2535 - val_accuracy: 0.6585 - val_f1_score: 0.7566 - val_precision: 1.0000 - val_recall: 0.6233
# Epoch 7/10
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0187 - accuracy: 0.9574 - f1_score: 0.8002 - precision: 1.0000 - recall: 0.6708 - val_loss: 0.2509 - val_accuracy: 0.6585 - val_f1_score: 0.7566 - val_precision: 1.0000 - val_recall: 0.6233
# Epoch 8/10
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0040 - accuracy: 1.0000 - f1_score: 0.7795 - precision: 1.0000 - recall: 0.6458 - val_loss: 0.2478 - val_accuracy: 0.5854 - val_f1_score: 0.7708 - val_precision: 1.0000 - val_recall: 0.6389
# Epoch 9/10
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0156 - accuracy: 0.9681 - f1_score: 0.7793 - precision: 1.0000 - recall: 0.6396 - val_loss: 0.2467 - val_accuracy: 0.6098 - val_f1_score: 0.7844 - val_precision: 1.0000 - val_recall: 0.6545
# Epoch 10/10
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0059 - accuracy: 0.9894 - f1_score: 0.7950 - precision: 1.0000 - recall: 0.6597 - val_loss: 0.2469 - val_accuracy: 0.6098 - val_f1_score: 0.7844 - val_precision: 1.0000 - val_recall: 0.6545
# Epoch 1/10
# 3/3 [==============================] - 2s 244ms/step - loss: 0.3543 - accuracy: 0.4468 - f1_score: 0.5647 - precision: 1.0000 - recall: 0.3944 - val_loss: 0.2197 - val_accuracy: 0.6585 - val_f1_score: 0.5892 - val_precision: 1.0000 - val_recall: 0.4549
# Epoch 2/10
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1319 - accuracy: 0.8298 - f1_score: 0.7025 - precision: 1.0000 - recall: 0.5424 - val_loss: 0.1961 - val_accuracy: 0.7073 - val_f1_score: 0.7753 - val_precision: 1.0000 - val_recall: 0.6372
# Epoch 3/10
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0632 - accuracy: 0.9362 - f1_score: 0.7550 - precision: 1.0000 - recall: 0.6076 - val_loss: 0.1792 - val_accuracy: 0.7561 - val_f1_score: 0.7753 - val_precision: 1.0000 - val_recall: 0.6372
# Epoch 4/10
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0431 - accuracy: 0.9574 - f1_score: 0.7866 - precision: 1.0000 - recall: 0.6493 - val_loss: 0.1662 - val_accuracy: 0.8049 - val_f1_score: 0.8557 - val_precision: 1.0000 - val_recall: 0.7483
# Epoch 5/10
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0199 - accuracy: 0.9681 - f1_score: 0.7791 - precision: 1.0000 - recall: 0.6382 - val_loss: 0.1589 - val_accuracy: 0.7805 - val_f1_score: 0.8661 - val_precision: 1.0000 - val_recall: 0.7639
# Epoch 6/10
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0191 - accuracy: 0.9894 - f1_score: 0.7787 - precision: 1.0000 - recall: 0.6396 - val_loss: 0.1539 - val_accuracy: 0.7805 - val_f1_score: 0.8661 - val_precision: 1.0000 - val_recall: 0.7639
# Epoch 7/10
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0194 - accuracy: 0.9894 - f1_score: 0.7892 - precision: 1.0000 - recall: 0.6569 - val_loss: 0.1545 - val_accuracy: 0.7805 - val_f1_score: 0.8661 - val_precision: 1.0000 - val_recall: 0.7639
# Epoch 8/10
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0063 - accuracy: 1.0000 - f1_score: 0.7841 - precision: 1.0000 - recall: 0.6472 - val_loss: 0.1514 - val_accuracy: 0.8293 - val_f1_score: 0.9092 - val_precision: 1.0000 - val_recall: 0.8351
# Epoch 9/10
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0196 - accuracy: 0.9681 - f1_score: 0.8093 - precision: 1.0000 - recall: 0.6826 - val_loss: 0.1484 - val_accuracy: 0.8293 - val_f1_score: 0.9092 - val_precision: 1.0000 - val_recall: 0.8351
# Epoch 10/10
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0093 - accuracy: 0.9787 - f1_score: 0.7866 - precision: 1.0000 - recall: 0.6493 - val_loss: 0.1451 - val_accuracy: 0.8293 - val_f1_score: 0.9092 - val_precision: 1.0000 - val_recall: 0.8351
# Epoch 1/10
# 3/3 [==============================] - 2s 151ms/step - loss: 0.4343 - accuracy: 0.3191 - f1_score: 0.1709 - precision: 1.0000 - recall: 0.0958 - val_loss: 0.3154 - val_accuracy: 0.5366 - val_f1_score: 0.3381 - val_precision: 1.0000 - val_recall: 0.2118
# Epoch 2/10
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2425 - accuracy: 0.6702 - f1_score: 0.5911 - precision: 1.0000 - recall: 0.4292 - val_loss: 0.2529 - val_accuracy: 0.6098 - val_f1_score: 0.3889 - val_precision: 1.0000 - val_recall: 0.2587
# Epoch 3/10
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1435 - accuracy: 0.8191 - f1_score: 0.7045 - precision: 1.0000 - recall: 0.5549 - val_loss: 0.2172 - val_accuracy: 0.7317 - val_f1_score: 0.5833 - val_precision: 1.0000 - val_recall: 0.4167
# Epoch 4/10
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0986 - accuracy: 0.9043 - f1_score: 0.7469 - precision: 1.0000 - recall: 0.5965 - val_loss: 0.1928 - val_accuracy: 0.7561 - val_f1_score: 0.7041 - val_precision: 1.0000 - val_recall: 0.5434
# Epoch 5/10
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0711 - accuracy: 0.9468 - f1_score: 0.7772 - precision: 1.0000 - recall: 0.6375 - val_loss: 0.1789 - val_accuracy: 0.7805 - val_f1_score: 0.7725 - val_precision: 1.0000 - val_recall: 0.6302
# Epoch 6/10
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0560 - accuracy: 0.9681 - f1_score: 0.8250 - precision: 1.0000 - recall: 0.7028 - val_loss: 0.1735 - val_accuracy: 0.7561 - val_f1_score: 0.8074 - val_precision: 1.0000 - val_recall: 0.6771
# Epoch 7/10
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0318 - accuracy: 1.0000 - f1_score: 0.8177 - precision: 1.0000 - recall: 0.6917 - val_loss: 0.1724 - val_accuracy: 0.7561 - val_f1_score: 0.8286 - val_precision: 1.0000 - val_recall: 0.7083
# Epoch 8/10
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0197 - accuracy: 1.0000 - f1_score: 0.8159 - precision: 1.0000 - recall: 0.6944 - val_loss: 0.1750 - val_accuracy: 0.7561 - val_f1_score: 0.8286 - val_precision: 1.0000 - val_recall: 0.7083
# Epoch 9/10
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0187 - accuracy: 1.0000 - f1_score: 0.8131 - precision: 1.0000 - recall: 0.6944 - val_loss: 0.1780 - val_accuracy: 0.7073 - val_f1_score: 0.8483 - val_precision: 1.0000 - val_recall: 0.7396
# Epoch 10/10
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0226 - accuracy: 1.0000 - f1_score: 0.8171 - precision: 1.0000 - recall: 0.6910 - val_loss: 0.1814 - val_accuracy: 0.7317 - val_f1_score: 0.8858 - val_precision: 1.0000 - val_recall: 0.7951
# Epoch 1/10
# 3/3 [==============================] - 2s 191ms/step - loss: 0.3778 - accuracy: 0.4255 - f1_score: 0.2374 - precision: 1.0000 - recall: 0.1375 - val_loss: 0.3505 - val_accuracy: 0.5366 - val_f1_score: 0.4881 - val_precision: 1.0000 - val_recall: 0.3229
# Epoch 2/10
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1972 - accuracy: 0.6702 - f1_score: 0.5273 - precision: 1.0000 - recall: 0.3646 - val_loss: 0.2908 - val_accuracy: 0.5854 - val_f1_score: 0.6546 - val_precision: 1.0000 - val_recall: 0.4878
# Epoch 3/10
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0997 - accuracy: 0.8723 - f1_score: 0.7202 - precision: 1.0000 - recall: 0.5660 - val_loss: 0.2522 - val_accuracy: 0.6098 - val_f1_score: 0.7534 - val_precision: 1.0000 - val_recall: 0.6059
# Epoch 4/10
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0611 - accuracy: 0.9574 - f1_score: 0.7502 - precision: 1.0000 - recall: 0.6042 - val_loss: 0.2270 - val_accuracy: 0.6585 - val_f1_score: 0.7957 - val_precision: 1.0000 - val_recall: 0.6684
# Epoch 5/10
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0396 - accuracy: 0.9787 - f1_score: 0.7684 - precision: 1.0000 - recall: 0.6299 - val_loss: 0.2095 - val_accuracy: 0.6585 - val_f1_score: 0.7957 - val_precision: 1.0000 - val_recall: 0.6684
# Epoch 6/10
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0188 - accuracy: 1.0000 - f1_score: 0.7849 - precision: 1.0000 - recall: 0.6507 - val_loss: 0.1996 - val_accuracy: 0.6829 - val_f1_score: 0.8054 - val_precision: 1.0000 - val_recall: 0.6840
# Epoch 7/10
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0192 - accuracy: 1.0000 - f1_score: 0.7866 - precision: 1.0000 - recall: 0.6493 - val_loss: 0.1910 - val_accuracy: 0.7317 - val_f1_score: 0.8858 - val_precision: 1.0000 - val_recall: 0.7951
# Epoch 8/10
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0122 - accuracy: 1.0000 - f1_score: 0.7870 - precision: 1.0000 - recall: 0.6500 - val_loss: 0.1868 - val_accuracy: 0.7561 - val_f1_score: 0.8951 - val_precision: 1.0000 - val_recall: 0.8108
# Epoch 9/10
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0136 - accuracy: 1.0000 - f1_score: 0.7843 - precision: 1.0000 - recall: 0.6472 - val_loss: 0.1838 - val_accuracy: 0.7561 - val_f1_score: 0.8951 - val_precision: 1.0000 - val_recall: 0.8108
# Epoch 10/10
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0085 - accuracy: 1.0000 - f1_score: 0.7824 - precision: 1.0000 - recall: 0.6479 - val_loss: 0.1816 - val_accuracy: 0.8049 - val_f1_score: 0.9129 - val_precision: 1.0000 - val_recall: 0.8420
# Epoch 1/10
# 3/3 [==============================] - 1s 177ms/step - loss: 0.2409 - accuracy: 0.6596 - f1_score: 0.9729 - precision: 1.0000 - recall: 0.9479 - val_loss: 0.2447 - val_accuracy: 0.5854 - val_f1_score: 0.9460 - val_precision: 1.0000 - val_recall: 0.8976
# Epoch 2/10
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1249 - accuracy: 0.7979 - f1_score: 0.9307 - precision: 1.0000 - recall: 0.8715 - val_loss: 0.2322 - val_accuracy: 0.6585 - val_f1_score: 0.9373 - val_precision: 1.0000 - val_recall: 0.8819
# Epoch 3/10
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0804 - accuracy: 0.8936 - f1_score: 0.8871 - precision: 1.0000 - recall: 0.7979 - val_loss: 0.2349 - val_accuracy: 0.6341 - val_f1_score: 0.8858 - val_precision: 1.0000 - val_recall: 0.7951
# Epoch 4/10
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0587 - accuracy: 0.9149 - f1_score: 0.8585 - precision: 1.0000 - recall: 0.7556 - val_loss: 0.2345 - val_accuracy: 0.6098 - val_f1_score: 0.8286 - val_precision: 1.0000 - val_recall: 0.7083
# Epoch 5/10
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0323 - accuracy: 0.9894 - f1_score: 0.8228 - precision: 1.0000 - recall: 0.7028 - val_loss: 0.2344 - val_accuracy: 0.6341 - val_f1_score: 0.8182 - val_precision: 1.0000 - val_recall: 0.6927
# Epoch 6/10
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0393 - accuracy: 0.9574 - f1_score: 0.8122 - precision: 1.0000 - recall: 0.6924 - val_loss: 0.2364 - val_accuracy: 0.6341 - val_f1_score: 0.8182 - val_precision: 1.0000 - val_recall: 0.6927
# Epoch 7/10
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0303 - accuracy: 0.9787 - f1_score: 0.8321 - precision: 1.0000 - recall: 0.7146 - val_loss: 0.2361 - val_accuracy: 0.6829 - val_f1_score: 0.7962 - val_precision: 1.0000 - val_recall: 0.6615
# Epoch 8/10
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0224 - accuracy: 0.9787 - f1_score: 0.8311 - precision: 1.0000 - recall: 0.7125 - val_loss: 0.2358 - val_accuracy: 0.6829 - val_f1_score: 0.7962 - val_precision: 1.0000 - val_recall: 0.6615
# Epoch 9/10
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0100 - accuracy: 1.0000 - f1_score: 0.8145 - precision: 1.0000 - recall: 0.6896 - val_loss: 0.2359 - val_accuracy: 0.6829 - val_f1_score: 0.7962 - val_precision: 1.0000 - val_recall: 0.6615
# Epoch 10/10
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0161 - accuracy: 0.9894 - f1_score: 0.8230 - precision: 1.0000 - recall: 0.7007 - val_loss: 0.2341 - val_accuracy: 0.7073 - val_f1_score: 0.7846 - val_precision: 1.0000 - val_recall: 0.6458
# Epoch 1/10
# 3/3 [==============================] - 2s 180ms/step - loss: 0.2534 - accuracy: 0.6809 - f1_score: 0.9369 - precision: 1.0000 - recall: 0.8819 - val_loss: 0.2418 - val_accuracy: 0.6585 - val_f1_score: 0.9576 - val_precision: 1.0000 - val_recall: 0.9219
# Epoch 2/10
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1034 - accuracy: 0.8404 - f1_score: 0.9316 - precision: 1.0000 - recall: 0.8729 - val_loss: 0.2324 - val_accuracy: 0.6585 - val_f1_score: 0.9921 - val_precision: 1.0000 - val_recall: 0.9844
# Epoch 3/10
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0536 - accuracy: 0.9255 - f1_score: 0.8809 - precision: 1.0000 - recall: 0.7875 - val_loss: 0.2267 - val_accuracy: 0.6585 - val_f1_score: 0.9921 - val_precision: 1.0000 - val_recall: 0.9844
# Epoch 4/10
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0270 - accuracy: 0.9468 - f1_score: 0.8658 - precision: 1.0000 - recall: 0.7646 - val_loss: 0.2233 - val_accuracy: 0.6829 - val_f1_score: 0.9839 - val_precision: 1.0000 - val_recall: 0.9688
# Epoch 5/10
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0257 - accuracy: 0.9574 - f1_score: 0.8562 - precision: 1.0000 - recall: 0.7528 - val_loss: 0.2245 - val_accuracy: 0.7073 - val_f1_score: 0.9754 - val_precision: 1.0000 - val_recall: 0.9531
# Epoch 6/10
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0185 - accuracy: 0.9681 - f1_score: 0.8528 - precision: 1.0000 - recall: 0.7458 - val_loss: 0.2248 - val_accuracy: 0.7317 - val_f1_score: 0.9460 - val_precision: 1.0000 - val_recall: 0.8976
# Epoch 7/10
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0125 - accuracy: 1.0000 - f1_score: 0.8297 - precision: 1.0000 - recall: 0.7118 - val_loss: 0.2271 - val_accuracy: 0.7317 - val_f1_score: 0.9460 - val_precision: 1.0000 - val_recall: 0.8976
# Epoch 8/10
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0200 - accuracy: 0.9894 - f1_score: 0.8392 - precision: 1.0000 - recall: 0.7243 - val_loss: 0.2284 - val_accuracy: 0.7317 - val_f1_score: 0.9460 - val_precision: 1.0000 - val_recall: 0.8976
# Epoch 9/10
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0204 - accuracy: 0.9894 - f1_score: 0.8217 - precision: 1.0000 - recall: 0.7021 - val_loss: 0.2300 - val_accuracy: 0.7317 - val_f1_score: 0.9460 - val_precision: 1.0000 - val_recall: 0.8976
# Epoch 10/10
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0086 - accuracy: 1.0000 - f1_score: 0.8301 - precision: 1.0000 - recall: 0.7160 - val_loss: 0.2330 - val_accuracy: 0.7317 - val_f1_score: 0.9460 - val_precision: 1.0000 - val_recall: 0.8976

# %% [markdown]
# ### Valeurs des métriques pour chaque dataset

# %%
best_train_accuracy = []
best_test_accuracy = []
best_train_f1_score = []
best_test_f1_score = []
best_train_precision = []
best_test_precision = []
best_train_recall = []
best_test_recall = []

for i in range(15):
    best_train_accuracy.append(history[i].history['accuracy'][np.argmin(history[i].history['loss'])])
    best_test_accuracy.append(history[i].history['val_accuracy'][np.argmin(history[i].history['val_loss'])])
    best_train_f1_score.append(history[i].history['f1_score'][np.argmin(history[i].history['loss'])])
    best_test_f1_score.append(history[i].history['val_f1_score'][np.argmin(history[i].history['val_loss'])])
    best_train_precision.append(history[i].history['precision'][np.argmin(history[i].history['loss'])])
    best_test_precision.append(history[i].history['val_precision'][np.argmin(history[i].history['val_loss'])])
    best_train_recall.append(history[i].history['recall'][np.argmin(history[i].history['loss'])])
    best_test_recall.append(history[i].history['val_recall'][np.argmin(history[i].history['val_loss'])])
    
    
for i in range(15):   
    print("best_train_accuracy for dataset",i+1," = ", best_train_accuracy[i])
    print("best_test_accuracy for dataset",i+1," = ", best_test_accuracy[i])
    print("best_train_f1_score for dataset",i+1," = ", best_train_f1_score[i])
    print("best_test_f1_score for dataset",i+1," = ", best_test_f1_score[i])
    print("best_train_precision for dataset",i+1," = ", best_train_precision[i])
    print("best_test_precision for dataset",i+1," = ", best_test_precision[i])
    print("best_train_recall for dataset",i+1," = ", best_train_recall[i])
    print("best_test_recall for dataset",i+1," = ", best_test_recall[i])
    print(" ")
# Out:
# best_train_accuracy for dataset 1  =  0.9893617033958435
# best_test_accuracy for dataset 1  =  0.8048780560493469
# best_train_f1_score for dataset 1  =  0.7790644764900208
# best_test_f1_score for dataset 1  =  0.970588207244873
# best_train_precision for dataset 1  =  1.0
# best_test_precision for dataset 1  =  1.0
# best_train_recall for dataset 1  =  0.6381944417953491
# best_test_recall for dataset 1  =  0.9444444179534912
#
# best_train_accuracy for dataset 2  =  0.978723406791687
# best_test_accuracy for dataset 2  =  0.7317073345184326
# best_train_f1_score for dataset 2  =  0.815756618976593
# best_test_f1_score for dataset 2  =  0.8482758402824402
# best_train_precision for dataset 2  =  1.0
# best_test_precision for dataset 2  =  1.0
# best_train_recall for dataset 2  =  0.6986110806465149
# best_test_recall for dataset 2  =  0.7395833730697632
#
# best_train_accuracy for dataset 3  =  0.978723406791687
# best_test_accuracy for dataset 3  =  0.6585366129875183
# best_train_f1_score for dataset 3  =  0.794259250164032
# best_test_f1_score for dataset 3  =  0.7857142686843872
# best_train_precision for dataset 3  =  1.0
# best_test_precision for dataset 3  =  1.0
# best_train_recall for dataset 3  =  0.6590277552604675
# best_test_recall for dataset 3  =  0.6527777910232544
#
# best_train_accuracy for dataset 4  =  0.9893617033958435
# best_test_accuracy for dataset 4  =  0.6585366129875183
# best_train_f1_score for dataset 4  =  0.8397009372711182
# best_test_f1_score for dataset 4  =  0.8951270580291748
# best_train_precision for dataset 4  =  1.0
# best_test_precision for dataset 4  =  1.0
# best_train_recall for dataset 4  =  0.7243055701255798
# best_test_recall for dataset 4  =  0.8107638955116272
#
# best_train_accuracy for dataset 5  =  1.0
# best_test_accuracy for dataset 5  =  0.6585366129875183
# best_train_f1_score for dataset 5  =  0.8008391261100769
# best_test_f1_score for dataset 5  =  0.8337263464927673
# best_train_precision for dataset 5  =  1.0
# best_test_precision for dataset 5  =  1.0
# best_train_recall for dataset 5  =  0.6715278029441833
# best_test_recall for dataset 5  =  0.7170138955116272
#
# best_train_accuracy for dataset 6  =  0.9893617033958435
# best_test_accuracy for dataset 6  =  0.8048780560493469
# best_train_f1_score for dataset 6  =  0.785454511642456
# best_test_f1_score for dataset 6  =  0.7857142686843872
# best_train_precision for dataset 6  =  1.0
# best_test_precision for dataset 6  =  1.0
# best_train_recall for dataset 6  =  0.6493055820465088
# best_test_recall for dataset 6  =  0.6527777910232544
#
# best_train_accuracy for dataset 7  =  1.0
# best_test_accuracy for dataset 7  =  0.6585366129875183
# best_train_f1_score for dataset 7  =  0.807319164276123
# best_test_f1_score for dataset 7  =  0.7857142686843872
# best_train_precision for dataset 7  =  1.0
# best_test_precision for dataset 7  =  1.0
# best_train_recall for dataset 7  =  0.6791666150093079
# best_test_recall for dataset 7  =  0.6527777910232544
#
# best_train_accuracy for dataset 8  =  0.9893617033958435
# best_test_accuracy for dataset 8  =  0.7317073345184326
# best_train_f1_score for dataset 8  =  0.8014421463012695
# best_test_f1_score for dataset 8  =  0.9188640117645264
# best_train_precision for dataset 8  =  1.0
# best_test_precision for dataset 8  =  1.0
# best_train_recall for dataset 8  =  0.6694443821907043
# best_test_recall for dataset 8  =  0.8506944179534912
#
# best_train_accuracy for dataset 9  =  0.9468085169792175
# best_test_accuracy for dataset 9  =  0.6829268336296082
# best_train_f1_score for dataset 9  =  0.8466272950172424
# best_test_f1_score for dataset 9  =  0.912909746170044
# best_train_precision for dataset 9  =  1.0
# best_test_precision for dataset 9  =  1.0
# best_train_recall for dataset 9  =  0.7347221970558167
# best_test_recall for dataset 9  =  0.8420138955116272
#
# best_train_accuracy for dataset 10  =  1.0
# best_test_accuracy for dataset 10  =  0.5853658318519592
# best_train_f1_score for dataset 10  =  0.7795413136482239
# best_test_f1_score for dataset 10  =  0.8221153020858765
# best_train_precision for dataset 10  =  1.0
# best_test_precision for dataset 10  =  1.0
# best_train_recall for dataset 10  =  0.6458333134651184
# best_test_recall for dataset 10  =  0.7013888955116272
#
# best_train_accuracy for dataset 11  =  1.0
# best_test_accuracy for dataset 11  =  0.8292682766914368
# best_train_f1_score for dataset 11  =  0.784073531627655
# best_test_f1_score for dataset 11  =  0.9091846942901611
# best_train_precision for dataset 11  =  1.0
# best_test_precision for dataset 11  =  1.0
# best_train_recall for dataset 11  =  0.6472222208976746
# best_test_recall for dataset 11  =  0.8350694179534912
#
# best_train_accuracy for dataset 12  =  1.0
# best_test_accuracy for dataset 12  =  0.7560975551605225
# best_train_f1_score for dataset 12  =  0.8131105899810791
# best_test_f1_score for dataset 12  =  0.8285714387893677
# best_train_precision for dataset 12  =  1.0
# best_test_precision for dataset 12  =  1.0
# best_train_recall for dataset 12  =  0.6944444179534912
# best_test_recall for dataset 12  =  0.7083333730697632
#
# best_train_accuracy for dataset 13  =  1.0
# best_test_accuracy for dataset 13  =  0.8048780560493469
# best_train_f1_score for dataset 13  =  0.7823975682258606
# best_test_f1_score for dataset 13  =  0.912909746170044
# best_train_precision for dataset 13  =  1.0
# best_test_precision for dataset 13  =  1.0
# best_train_recall for dataset 13  =  0.6479166746139526
# best_test_recall for dataset 13  =  0.8420138955116272
#
# best_train_accuracy for dataset 14  =  1.0
# best_test_accuracy for dataset 14  =  0.6585366129875183
# best_train_f1_score for dataset 14  =  0.8145020604133606
# best_test_f1_score for dataset 14  =  0.9372548460960388
# best_train_precision for dataset 14  =  1.0
# best_test_precision for dataset 14  =  1.0
# best_train_recall for dataset 14  =  0.6895833015441895
# best_test_recall for dataset 14  =  0.8819444179534912
#
# best_train_accuracy for dataset 15  =  1.0
# best_test_accuracy for dataset 15  =  0.6829268336296082
# best_train_f1_score for dataset 15  =  0.8300849795341492
# best_test_f1_score for dataset 15  =  0.9838709235191345
# best_train_precision for dataset 15  =  1.0
# best_test_precision for dataset 15  =  1.0
# best_train_recall for dataset 15  =  0.7159722447395325
# best_test_recall for dataset 15  =  0.96875

# %% [markdown]
# #### Moyenne des valeurs des métriques pour chaque Dataset

# %%
print("Mean of test accuracy for the 15 dataset = ", np.mean(best_test_accuracy))
print("Mean of test f1_score for the 15 dataset = ", np.mean(best_test_f1_score))
print("Mean of test precision for the 15 dataset = ", np.mean(best_test_precision))
print("Mean of test recall for the 15 dataset = ", np.mean(best_test_recall))
# Out:
# Mean of test accuracy for the 15 dataset =  0.7138211488723755
# Mean of test f1_score for the 15 dataset =  0.875369397799174
# Mean of test precision for the 15 dataset =  1.0
# Mean of test recall for the 15 dataset =  0.786689817905426

# %% [markdown]
# ## Metrics Visualization

# %%
n=2
def plot_metrics(hist):
    
    # summarize history for accuracy
    plt.subplot(n, 5, 1)
    plt.plot(hist.history['accuracy'])
    plt.plot(hist.history['val_accuracy'])
    plt.title('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    
    # summarize history for loss
    plt.subplot(n, 5, 2)
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('loss')
    plt.xlabel('epoch')
    
    # summarize history for f1_score
    plt.subplot(n, 5, 3)
    plt.plot(hist.history['f1_score'])
    plt.plot(hist.history['val_f1_score'])
    plt.title('f1_score')
    plt.xlabel('epoch')
    
    # summarize history for precision
    plt.subplot(n, 5, 4)
    plt.plot(hist.history['precision'])
    plt.plot(hist.history['val_precision'])
    plt.title('precision')
    plt.xlabel('epoch')
    
    # summarize history for recall
    plt.subplot(n, 5, 5)
    plt.plot(hist.history['recall'])
    plt.plot(hist.history['val_recall'])
    plt.title('recall')
    plt.xlabel('epoch')
    
    plt.show()

# %%
for i in range(15):    
    print("DATASET",i+1)
    plot_metrics(history[i])
# Out:
# DATASET 1
# DATASET 2
# DATASET 3
# DATASET 4
# DATASET 5
# DATASET 6
# DATASET 7
# DATASET 8
# DATASET 9
# DATASET 10
# DATASET 11
# DATASET 12
# DATASET 13
# DATASET 14
# DATASET 15

# %% [markdown]
# ### Courbe ROC

# %%
auc_keras = []
fpr = []
tpr = []

for i in range(15):
    y_pred = ANN[i].predict(X_test[i]).ravel()
    fpr_i, tpr_i, thresholds = roc_curve(y_test[i], y_pred)
    fpr.append(fpr_i)
    tpr.append(tpr_i)
    auc_keras.append(auc(fpr_i, tpr_i))
    


# Plot ROC Curve
for i in range(15):
    print('DATASET ', i+1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr[i], tpr[i], label='area = {:.3f})'.format(auc_keras[i]))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.show()
# Out:
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fbb4f7aa790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 10ms/step
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fbb4ffdcb80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# DATASET  1
# DATASET  2
# DATASET  3
# DATASET  4
# DATASET  5
# DATASET  6
# DATASET  7
# DATASET  8
# DATASET  9
# DATASET  10
# DATASET  11
# DATASET  12
# DATASET  13
# DATASET  14
# DATASET  15

# %% [markdown]
# ### Matrice de Confusion

# %% [markdown]
# #### Matrice de Confusion du Test

# %%
#Predict
y_pred = []
labels = ["Echecs", "Réussites"]
for i in range(15):
    y_prediction = ANN[i].predict(X_test[i])
    y_prediction = y_prediction>0.5
    y_pred.append(y_prediction)
    
#Create confusion matrix and normalizes it over predicted (columns)
for i in range(15):
    print('DATASET',i+1)
    cm = confusion_matrix(y_test[i], y_pred[i])
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot(cmap=plt.cm.Blues)
    plt.show()
# Out:
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 8ms/step
# DATASET 1
# DATASET 2
# DATASET 3
# DATASET 4
# DATASET 5
# DATASET 6
# DATASET 7
# DATASET 8
# DATASET 9
# DATASET 10
# DATASET 11
# DATASET 12
# DATASET 13
# DATASET 14
# DATASET 15

# %% [markdown]
# => Peut-être dû au fait qu'on a des données déséquilibrées (94/135 Réussites et seulement 41/135 Echecs)
